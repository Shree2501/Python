# %%
book={}
book["tom"]={
    'name':'tom',
    'phone':236346775,
    'address':'indore'
}
book["bob"]={
    'name':'bob',
    'phone':236375643,
    'address':'dhar'
}
print(book["bob"])
print(book["bob"]["phone"])
print(book["tom"]["address"])
print(type(book))
print()
for i in book:
  print(book[i])
# Out:
# {'name': 'bob', 'phone': 236375643, 'address': 'dhar'}
# 236375643
# indore
# <class 'dict'>
#
# {'name': 'tom', 'phone': 236346775, 'address': 'indore'}
# {'name': 'bob', 'phone': 236375643, 'address': 'dhar'}
