# %%
s1 = {1,"a",True,2,"b",False}
s1.add("Hello")
s1
# Out:
# {1, 2, False, 'Hello', 'a', 'b'}

# %%
s1.update([10,20,30])
s1
# Out:
# {1, 10, 2, 20, 30, False, 'a', 'b'}

# %%
s1.remove(False)
s1
# Out:
# {1, 10, 2, 20, 30, 'a', 'b'}

# %%
s1 = {1,2,3}
s2 = {2,"a","b","c"}
print(s1|s2)
print(s1.union(s2))
print(s1&s2)
print(s1.intersection(s2))
print(s1-s2)
# Out:
# {1, 2, 3, 'c', 'b', 'a'}
# {1, 2, 3, 'c', 'b', 'a'}
# {2}
# {2}
# {1, 3}
