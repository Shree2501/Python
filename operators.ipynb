# %%
a=60
b=13
print(a & b)
print(a | b)
print(a ^ b)
print(~a)
print(~b)
print(a<<2)
print(a>>2)
# Out:
# 12
# 61
# 49
# -61
# -14
# 240
# 15

# %%
name="shree"
print('S' in name)
print('S' not in name)
# Out:
# False
# True

# %%
a=60
b=60
x=[1,2,3]
y=[1,2,3]
p="Shree"
q="Shree"
print(a is b);
print(x is y); #False bcoz of memory location
print(p is q);
# Out:
# True
# False
# True
