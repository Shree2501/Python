# %%
#Game pro
import random
yourGuess=int(input("Enter your guess number (0-10): "))
ch=0
while True:
  GameNum=random.randrange(1,10)
  while True:
    if GameNum == yourGuess:
      print("Congrats!🎉 you guessed right number")
      break
    elif GameNum<yourGuess:
      print("Your Guess is greater than target")
      yourGuess=int(input("Enter your guess again: "))
    elif GameNum>yourGuess:
      print("Your Guess is smaller than target")
      yourGuess=int(input("Enter your guess again: "))
    else:
      print("Wrong guess! Please guess again")
      yourGuess=int(input("Enter your guess again: "))
  ch=input("Do you want to play this game again (y/n)")
  if ch=='y':
    continue
  else:
    print("Exited")
    break
# Out:
# Your Guess is greater than target
# Congrats!🎉 you guessed right number
# Exited
