# %%
d={"Shree":6268560775,"Hari":5937416472}
d
# Out:
# {'Shree': 6268560775, 'Hari': 5937416472}

# %%
d={"Shree":6268560775,"Hari":5937416472}
d["Shree"]
# Out:
# 6268560775

# %%
d={"Shree":6268560775,"Hari":5937416472}
d["sam"]=2452626436
d
# Out:
# {'Shree': 6268560775, 'Hari': 5937416472, 'sam': 2452626436}

# %%
d={"Shree":6268560775,"Hari":5937416472}
d["sam"]=2452626436
del d["sam"]
d
# Out:
# {'Shree': 6268560775, 'Hari': 5937416472}

# %%
d={"Shree":6268560775,"Hari":5937416472}
for key in d:
  print("key:",key,"value:",d[key])
# Out:
# key: Shree value: 6268560775
# key: Hari value: 5937416472

# %%
d={"Shree":6268560775,"Hari":5937416472}
print("Hari" in d)
print("sam" in d)
# Out:
# True
# False

# %%
d={"Shree":6268560775,"Hari":5937416472}
d.clear()
d
# Out:
# {}

# %%
student = {"Name":"Ananya","age":20,"Course":"BTech CSE"}
print("Student Details:")
student
# Out:
# Student Details:
# {'Name': 'Ananya', 'age': 20, 'Course': 'BTech CSE'}

# %%
student={"name":"Shree","age":18}

for key in student:
  print(key)
  print(student[key])
print("-"*10)

for value in student.values():
  print(value)
  print("-"*10)

for key,value in student.items():
  print(key,value)
# Out:
# name
# Shree
# age
# 18
# ----------
# Shree
# ----------
# 18
# ----------
# name Shree
# age 18

# %%
students = {
    "student1":{
        "name":"Shree",
        "age":18,
        "grade":"A"
    },
    "student2":{
        "name":"Shreya",
        "age":38,
        "grade":"B"
    }
}
print(students["student1"]["name"])
# Out:
# Shree

# %%
student = {"Name":"Ananya","age":20,"Course":"BTech CSE"}
print("Student Details:")
student
del student["Course"]
print("After Deletion: ",student)
# Out:
# Student Details:
# After Deletion:  {'Name': 'Ananya', 'age': 20}

# %%
data = {"Python":90,"C":65,"Java":96}
key = input("Enter subject: ")
if key in data:
  print(f"Marks in {key}:",data[key])
else:
  print("Subject not found")
# Out:
# Enter subject: Python
# Marks in Python: 90

# %%
data = {"Python":90,"C":65,"Java":96}
print(data.keys())
print(data.values())
print(data.items())
# Out:
# dict_keys(['Python', 'C', 'Java'])
# dict_values([90, 65, 96])
# dict_items([('Python', 90), ('C', 65), ('Java', 96)])

# %%
original = {"a":1,"b":2,"c":3}
copy_dict = original.copy()
original.clear()
print(original)
print(copy_dict)
# Out:
# {}
# {'a': 1, 'b': 2, 'c': 3}

# %%
student = {"Aryan":96,"Riya":87}
topper = max(student, key=student.get)
print(topper)
# Out:
# Aryan

# %%
student = {
    "Name" : "Ananya",
    "Marks" : {"Maths":98,"Science":75,"CS":89}
}
avg=sum(student["Marks"].values())/len(student["Marks"])
print("Average marks of ",student["Name"],"=",avg)
# Out:
# Average marks of  Ananya = 87.33333333333333

# %%
prices={"Sugar":120,"Bread":1230,"Mobile":10000}
for item,price in prices.items():
  if price>1000:
    prices[item] = price * 0.1
print("Discount price : ",prices)
# Out:
# Discount price :  {'Sugar': 120, 'Bread': 123.0, 'Mobile': 1000.0}
