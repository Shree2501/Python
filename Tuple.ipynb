# %%
numbers = (1,2,-3)
print(numbers)
# Out:
# (1, 2, -3)

# %%
language =("python","C","C++")
print(language[1])
# Out:
# C

# %%
cars=("BMW","Tesla","FOrd")
cars[0]="Nissan"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3110105775.py in <cell line: 0>()
#       1 cars=("BMW","Tesla","FOrd")
# ----> 2 cars[0]="Nissan"
#
# TypeError: 'tuple' object does not support item assignment

# %%
cars=("BMW","Tesla","FOrd")
print(len(cars))
# Out:
# 3

# %%
cars=("BMW","Tesla","FOrd")
for car in cars:
  print(car)
# Out:
# BMW
# Tesla
# FOrd

# %%
cars=("BMW","Tesla","Ford")
print("BMW" in cars)
print("Audi" in cars)
# Out:
# True
# False

# %%
cars=("BMW","Tesla","FOrd")
del cars
print(cars)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2003791503.py in <cell line: 0>()
#       1 cars=("BMW","Tesla","FOrd")
#       2 del cars
# ----> 3 print(cars)
#
# NameError: name 'cars' is not defined
