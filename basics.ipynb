# %%
#Welcome to python
print("Hello World")
print('Hello World')
print("""Hello World""")
print('Murtazi','Kannodwali',sep="---")
# Out:
# Hello World
# Hello World
# Hello World
# Murtazi---Kannodwali

# %%
print('Hey Shree',end=' ')
print("Hello","How are you?")
# Out:
# Hey Shree Hello How are you?

# %%
print("Hello! "*3)
# Out:
# Hello! Hello! Hello!

# %%
print("HEllo","World",2025)
# Out:
# HEllo World 2025

# %%
print("Hello,%s!" % "World")  # %s replaces what we write after %
# Out:
# Hello,World!

# %%
import sys
sys.stdout.write("Hello,Shree!\n""Anu")
# Out:
# Hello,Shree!
# Anu
# 16

# %%
print("Hello,\"Python is fun!\"") # To print as it is
# Out:
# Hello,"Python is fun!"

# %%
print(f"{'Python':<10} is awesome") #Left align
print(f"{'Python':>10} is awesome") #Right align
print(f"{'Python':^20} is awesome") #Center in 20 spaces
# Out:
# Python     is awesome
#     Python is awesome
#        Python        is awesome

# %%
#addition of two numbers
a=10
b=4
print(a+b)
# Out:
# 14

# %%
#Multiplication
a = input("Enter the radius of circle: ")
b = input("Enter the radius of circle: ")
print("Multiplication is ",int(a)*int(b))
# Out:
# Enter the radius of circle: 4
# Enter the radius of circle: 4
# Multiplication is  16

# %%
#area of circle
radius = float(input("Enter the radius of circle: "))
area = print("Area of circle is: ",3.14*radius*radius)
# Out:
# Enter the radius of circle: 4
# Area of circle is:  50.24

# %%
x,y,z=("ANU")
print(x)
print(y)
print(z)
# Out:
# A
# N
# U

# %%
print("Shree the Sharma")
# Out:
# Shree the Sharma

# %%
#swapping
a=5
b=4
'''a,b = b,a
print(a)
print(b)'''

'''a=a+b
b=a-b
a=a-b
print(a)
print(b)'''

'''c=b
b=a
a=c
print(a)
print(b)'''

a=a^b
b=a^b
a=a^b
print(a)
print(b)
# Out:
# 4
# 5

# %%
#Conversion
Celcius= int(input("Enter temp in celcius: "))
fahrenheit=Celcius*(9/5)+32
print("The temp in fahrenheit is:",fahrenheit,"fahrenheit")
# Out:
# Enter temp in celcius: 2
# The temp in fahrenheit is: 35.6 fahrenheit

# %%
#typecasting
a=2.5
print(int(a))
# Out:
# 2

# %%
#reverse of a 4digit number
'''a=2345
rev=0
d1=a%10*1000
a=a//10
d2=a%10*100
a=a//10
d3=a%10*10
a=a//10
d4=a
print(d1+d2+d3+d4)'''
# Out:
# 5432

# %%
quantity=int(input("Enter no. of items: "))
price=float(input("enter the price of product: "))
bill=quantity*price
print(bill)
# Out:
# Enter no. of items: 1
# enter the price of product: 1.234
# 1.234

# %%
#int datatype
a=1
b=-200
c=3000
print("a=",a)
print("b=",b)
print("c=",c)
# Out:
# a= 1
# b= -200
# c= 3000

# %%
#float datatype
a=1.23
b=-200.45
c=3.00056
print("a=",a)
print("b=",b)
print("c=",c)
# Out:
# a= 1.23
# b= -200.45
# c= 3.00056

# %%
#string datatype
a='Shree'
b='Sharma'
print(a,b,sep="the")
# Out:
# ShreetheSharma

# %%
#boolean datatype
a=True
b=False
print(a,b)
# Out:
# True False

# %%
Location,house = "Amjhera","Sharmadairy"
print(Location,house)
# Out:
# Amjhera Sharmadairy

# %%
name=surname="Shree"
print(name,surname)
# Out:
# Shree Shree

# %%
name = "Shree"
surname = name + 2
print(surname)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1527050550.py in <cell line: 0>()
#       1 name="Shree"
# ----> 2 surname=name + 2
#       3 print(surname)
#
# TypeError: can only concatenate str (not "int") to str

# %%
name="Shree"
print(name)
del name
print(name)
# Out:
# Shree
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-127745996.py in <cell line: 0>()
#       2 print(name)
#       3 del name
# ----> 4 print(name)
#
# NameError: name 'name' is not defined

# %%
num = 10
message = "The number is: "
result = message + str(num)
print(result)
# Out:
# The number is: 10

# %%
name = 'john'
print(name)
print(type(name))
# Out:
# john
# <class 'str'>

# %%
var = None

# %%
type(-1.24)
# Out:
# float

# %%
n=1.233267
print(round(n,2))
# Out:
# 1.23
